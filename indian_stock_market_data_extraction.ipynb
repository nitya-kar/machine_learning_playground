# %% [markdown]
# <a href="https://colab.research.google.com/github/nitya-kar/machine_learning_playground/blob/main/indian_stock_market_data_extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fetch daa from free API

# %%
import requests
import pandas as pd

# %%
header = {'x-rapidapi-host': 'indian-stock-exchange-api2.p.rapidapi.com', 'x-rapidapi-key': '8b2eaadad0msh9b14d4f94b2b4d6p1c33a0jsnc30c428da2e4'}

response = requests.get('https://indian-stock-exchange-api2.p.rapidapi.com/mutual_fund_search?query=nippon', headers = header)

# %%
df = pd.DataFrame(response.json())
# Out:
#             id                                         schemeName  \
# 0     MF000056  Nippon India Multi Cap Fund Direct Plan Payout...
# 1     MF000069          Nippon India Equity Savings Direct Growth
# 2     MF000021  Nippon India ELSS Tax Saver Fund Direct Plan P...
# 3     MF000022  Nippon India Equity Hybrid Fund - Direct Plan ...
# 4     MF000064           Nippon India Equity Savings Direct Bonus
# ...        ...                                                ...
# 1147  MF017391  Nippon India Nifty Realty Index Fund Direct Gr...
# 1148  MF016904  Nippon India Nifty 500 Equal Weight Index Fund...
# 1149  MF017401  Nippon India Nifty 500 Low Volatility 50 Index...
# 1150  MF017402  Nippon India Nifty 500 Quality 50 Index Fund D...
# 1151  MF016978  Nippon India Nifty 500 Momentum 50 Index Fund ...
#
#               isin                     schemeType categoryId
# 0     INF204K01XD4  Open Ended Investment Company   MFCAT003
# ...

# %%
df.reset_index(inplace=True,drop=True)

# %%
df
# Out:
#             id                                         schemeName  \
# 0     MF000056  Nippon India Multi Cap Fund Direct Plan Payout...
# 1     MF000069          Nippon India Equity Savings Direct Growth
# 2     MF000021  Nippon India ELSS Tax Saver Fund Direct Plan P...
# 3     MF000022  Nippon India Equity Hybrid Fund - Direct Plan ...
# 4     MF000064           Nippon India Equity Savings Direct Bonus
# ...        ...                                                ...
# 1147  MF017391  Nippon India Nifty Realty Index Fund Direct Gr...
# 1148  MF016904  Nippon India Nifty 500 Equal Weight Index Fund...
# 1149  MF017401  Nippon India Nifty 500 Low Volatility 50 Index...
# 1150  MF017402  Nippon India Nifty 500 Quality 50 Index Fund D...
# 1151  MF016978  Nippon India Nifty 500 Momentum 50 Index Fund ...
#
#               isin                     schemeType categoryId
# 0     INF204K01XD4  Open Ended Investment Company   MFCAT003
# ...

# %%
df.shape
# Out:
# (1152, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1152 entries, 0 to 1151
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1152 non-null   object
#  1   schemeName  1152 non-null   object
#  2   isin        1151 non-null   object
#  3   schemeType  1152 non-null   object
#  4   categoryId  1152 non-null   object
# dtypes: object(5)
# memory usage: 45.1+ KB
